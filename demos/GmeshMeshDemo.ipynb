# %% [markdown]
# # Demo for GmshMesh

# %%
# %load_ext autoreload
# %autoreload 2

from GmshMesh import GmshMesh

m = GmshMesh('gmsh/complex.msh')

print(m)
# Out:
# {"meshFormat": {"version": 4.1, "fileType": 0, "dataSize": 8}, "physicalNames": [{"dimension": 1, "tag": 1, "name": "c1"}, {"dimension": 2, "tag": 2, "name": "s1"}, {"dimension": 2, "tag": 3, "name": "s2"}, {"dimension": 2, "tag": 4, "name": "s3"}], "entities": {"points": [{"id": 5, "x": 0.5, "y": 0.3, "z": 0.0, "physicalTags": []}, {"id": 6, "x": 0.75, "y": 0.3, "z": 0.0, "physicalTags": []}, {"id": 7, "x": 0.75, "y": 0.8999999999999999, "z": 0.0, "physicalTags": []}, {"id": 8, "x": 0.5, "y": 0.8999999999999999, "z": 0.0, "physicalTags": []}, {"id": 9, "x": 0.0, "y": 0.0, "z": 0.0, "physicalTags": []}, {"id": 10, "x": 0.5, "y": 0.0, "z": 0.0, "physicalTags": []}, {"id": 11, "x": 0.5, "y": 1.0, "z": 0.0, "physicalTags": []}, {"id": 12, "x": 0.0, "y": 1.0, "z": 0.0, "physicalTags": []}, {"id": 13, "x": 0.75, "y": 0.0, "z": 0.0, "physicalTags": []}, {"id": 14, "x": 1.25, "y": 0.0, "z": 0.0, "physicalTags": []}, {"id": 15, "x": 1.25, "y": 0.5, "z": 0.0, "physicalTags": []}, {"id": 16, "
# ...
